# %%
from bluebook.generator import PromptBuilder

template = PromptBuilder.build_template_query()

# %%
PromptBuilder.verify_template_prompt(template)
# Out:
# True

# %%
new_template = """
        make questions for ##__EXAM_NAME_ANCHOR__##
        Your goal is to produce exactly ##__QUESTION_NUM_ANCHOR__## multiple-choice questions.
        Questions must mirror the style, rigor, and coverage of the actual ##__EXAM_NAME_ANCHOR__## exam.
        The student asked to focus on: “##__ADDITIONAL_REQUEST_ANCHOR__##”.
"""
PromptBuilder.verify_template_prompt(new_template)
# Out:
# True

# %%
prompt = PromptBuilder.build_custom_prompt(template_query=new_template, exam_name="FUN EXAM", question_num=11, additional_request="BE FUNX")
print(prompt)
# Out:
#         make questions for FUN EXAM
#         Your goal is to produce exactly 11 multiple-choice questions.
#         Questions must mirror the style, rigor, and coverage of the actual FUN EXAM exam.
#         The student asked to focus on: “BE FUNX”.
