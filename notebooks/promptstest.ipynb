# %%
from bluebook import database_manager
db = database_manager.Database()

# %%
print(db.select_all_prompts())
db.add_custom_prompt(name="test_prompt", prompt="TEST PROMPT")
print(db.select_all_prompts())
# Out:
# []
# [{'id': 1, 'name': 'test_prompt', 'prompt': 'TEST PROMPT'}]

# %%
db.select_all_prompts()
# Out:
# [{'id': 1, 'name': 'test_prompt', 'prompt': 'TEST PROMPT'}]

# %%
db.remove_prompt(prompt_id=1)
db.select_all_prompts()
# Out:
# []

# %%
db.select_all_exams()
# Out:
# [{'id': 0, 'name': 'CompTIA Security+'},
#  {'id': 1, 'name': 'CompTIA A+'},
#  {'id': 2, 'name': 'CompTIA Network+'},
#  {'id': 3, 'name': 'test exam'}]

# %%
db.add_custom_prompt(name="test_prompt", prompt="TEST PROMPT")
db.select_all_prompts()
# Out:
# [{'id': 1, 'name': 'test_prompt', 'prompt': 'TEST PROMPT'}]

# %%
db.add_prompt_exam_mapping(prompt_id=1, exam_id=3)
db.select_all_prompt_mappings()
# Out:
# [{'id': 1, 'prompt_id': 1, 'exam_id': 3}]

# %%
db.select_prompt_mappings(exam_id=3)
# Out:
# [{'id': 1, 'prompt_id': 1, 'exam_id': 3}]
